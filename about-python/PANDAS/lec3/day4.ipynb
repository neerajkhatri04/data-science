# %%
import pandas as pd

# %%
df  = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.drop("parch", axis=1, inplace=True)

# %%
df.drop(3, inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp     fare embarked   class    who  \
# 0           0       3    male  22.0      1   7.2500        S   Third    man
# 1           1       1  female  38.0      1  71.2833        C   First  woman
# 2           1       3  female  26.0      0   7.9250        S   Third  woman
# 4           0       3    male  35.0      0   8.0500        S   Third    man
# 5           0       3    male   NaN      0   8.4583        Q   Third    man
# ..        ...     ...     ...   ...    ...      ...      ...     ...    ...
# 886         0       2    male  27.0      0  13.0000        S  Second    man
# 887         1       1  female  19.0      0  30.0000        S   First  woman
# 888         0       3  female   NaN      1  23.4500        S   Third  woman
# 889         1       1    male  26.0      0  30.0000        C   First    man
# 890         0       3    male  32.0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df.set_index("pclass", inplace=True)

# %%
df
# Out:
#         survived     sex   age  sibsp     fare embarked   class    who  \
# pclass
# 3              0    male  22.0      1   7.2500        S   Third    man
# 1              1  female  38.0      1  71.2833        C   First  woman
# 3              1  female  26.0      0   7.9250        S   Third  woman
# 3              0    male  35.0      0   8.0500        S   Third    man
# 3              0    male   NaN      0   8.4583        Q   Third    man
# ...          ...     ...   ...    ...      ...      ...     ...    ...
# 2              0    male  27.0      0  13.0000        S  Second    man
# 1              1  female  19.0      0  30.0000        S   First  woman
# 3              0  female   NaN      1  23.4500        S   Third  woman
# 1              1    male  26.0      0  30.0000        C   First    man
# 3              0    male  32.0      0   7.7500        Q   Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      pclass  survived     sex   age  sibsp     fare embarked   class    who  \
# 0         3         0    male  22.0      1   7.2500        S   Third    man
# 1         1         1  female  38.0      1  71.2833        C   First  woman
# 2         3         1  female  26.0      0   7.9250        S   Third  woman
# 3         3         0    male  35.0      0   8.0500        S   Third    man
# 4         3         0    male   NaN      0   8.4583        Q   Third    man
# ..      ...       ...     ...   ...    ...      ...      ...     ...    ...
# 885       2         0    male  27.0      0  13.0000        S  Second    man
# 886       1         1  female  19.0      0  30.0000        S   First  woman
# 887       3         0  female   NaN      1  23.4500        S   Third  woman
# 888       1         1    male  26.0      0  30.0000        C   First    man
# 889       3         0    male  32.0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
di = {
    "key1": [2,3,4,5,6],
    "key2": ["a", "b", "c", "d", "e"],
    "key3": [10, 20, 30, 40, 50],
    "key4": [100, 200, 300, 400, 500]
}

# %%
pd.DataFrame(di)
# Out:
#    key1 key2  key3  key4
# 0     2    a    10   100
# 1     3    b    20   200
# 2     4    c    30   300
# 3     5    d    40   400
# 4     6    e    50   500

# %%
df.dropna()
# Out:
#      pclass  survived     sex   age  sibsp     fare embarked   class    who  \
# 1         1         1  female  38.0      1  71.2833        C   First  woman
# 5         1         0    male  54.0      0  51.8625        S   First    man
# 9         3         1  female   4.0      1  16.7000        S   Third  child
# 10        1         1  female  58.0      0  26.5500        S   First  woman
# 20        2         1    male  34.0      0  13.0000        S  Second    man
# ..      ...       ...     ...   ...    ...      ...      ...     ...    ...
# 870       1         1  female  47.0      1  52.5542        S   First  woman
# 871       1         0    male  33.0      0   5.0000        S   First    man
# 878       1         1  female  56.0      0  83.1583        C   First  woman
# 886       1         1  female  19.0      0  30.0000        S   First  woman
# 888       1         1    male  26.0      0  30.0000        C   First    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df
# Out:
#      pclass  survived     sex   age  sibsp     fare embarked   class    who  \
# 0         3         0    male  22.0      1   7.2500        S   Third    man
# 1         1         1  female  38.0      1  71.2833        C   First  woman
# 2         3         1  female  26.0      0   7.9250        S   Third  woman
# 3         3         0    male  35.0      0   8.0500        S   Third    man
# 4         3         0    male   NaN      0   8.4583        Q   Third    man
# ..      ...       ...     ...   ...    ...      ...      ...     ...    ...
# 885       2         0    male  27.0      0  13.0000        S  Second    man
# 886       1         1  female  19.0      0  30.0000        S   First  woman
# 887       3         0  female   NaN      1  23.4500        S   Third  woman
# 888       1         1    male  26.0      0  30.0000        C   First    man
# 889       3         0    male  32.0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df.dropna(axis=1)
# Out:
#      pclass  survived     sex  sibsp     fare   class    who  adult_male  \
# 0         3         0    male      1   7.2500   Third    man        True
# 1         1         1  female      1  71.2833   First  woman       False
# 2         3         1  female      0   7.9250   Third  woman       False
# 3         3         0    male      0   8.0500   Third    man        True
# 4         3         0    male      0   8.4583   Third    man        True
# ..      ...       ...     ...    ...      ...     ...    ...         ...
# 885       2         0    male      0  13.0000  Second    man        True
# 886       1         1  female      0  30.0000   First  woman       False
# 887       3         0  female      1  23.4500   Third  woman       False
# 888       1         1    male      0  30.0000   First    man        True
# 889       3         0    male      0   7.7500   Third    man        True
#
#     alive  alone
# 0      no  False
# 1     yes  False
# 2     yes   True
# 3      no   True
# ...

# %%
df.fillna("neeraj")
# Out:
#      pclass  survived     sex     age  sibsp     fare embarked   class    who  \
# 0         3         0    male    22.0      1   7.2500        S   Third    man
# 1         1         1  female    38.0      1  71.2833        C   First  woman
# 2         3         1  female    26.0      0   7.9250        S   Third  woman
# 3         3         0    male    35.0      0   8.0500        S   Third    man
# 4         3         0    male  neeraj      0   8.4583        Q   Third    man
# ..      ...       ...     ...     ...    ...      ...      ...     ...    ...
# 885       2         0    male    27.0      0  13.0000        S  Second    man
# 886       1         1  female    19.0      0  30.0000        S   First  woman
# 887       3         0  female  neeraj      1  23.4500        S   Third  woman
# 888       1         1    male    26.0      0  30.0000        C   First    man
# 889       3         0    male    32.0      0   7.7500        Q   Third    man
#
# ...

# %%
g1 = df.groupby("survived")

# %%
g1.sum()
# Out:
#           pclass                                                sex       age  \
# survived
# 0           1390  malemalemalemalemalemalemalefemalemalefemalema...  12985.50
# 1            666  femalefemalefemalefemalefemalefemalefemalemale...   8184.67
#
#           sibsp        fare  \
# survived
# 0           304  12142.7199
# 1           161  16498.1294
#
#                                                    embarked  \
# survived
# 0         SSQSSSSSQSSSCSSCSCSSSSSCSQCSSSCCSCSSCSSSSSCSSS...
# 1         CSSCSSSSCSQSSQCQCCCQQCSSSSCSSSSSSQSSSCSSSQSCSC...
#
#                                                       class  \
# survived
# 0         ThirdThirdThirdFirstThirdThirdThirdThirdThirdT...
# 1         FirstThirdThirdSecondThirdFirstSecondSecondThi...
#
#                                                         who  adult_male  \
# survived
# 0         manmanmanmanchildmanmanchildchildwomanmanchild...         449
# ...

# %%
g1.sum()
# Out:
#           pclass                                                sex       age  \
# survived
# 0           1390  malemalemalemalemalemalemalefemalemalefemalema...  12985.50
# 1            666  femalefemalefemalefemalefemalefemalefemalemale...   8184.67
#
#           sibsp        fare  \
# survived
# 0           304  12142.7199
# 1           161  16498.1294
#
#                                                    embarked  \
# survived
# 0         SSQSSSSSQSSSCSSCSCSSSSSCSQCSSSCCSCSSCSSSSSCSSS...
# 1         CSSCSSSSCSQSSQCQCCCQQCSSSSCSSSSSSQSSSCSSSQSCSC...
#
#                                                       class  \
# survived
# 0         ThirdThirdThirdFirstThirdThirdThirdThirdThirdT...
# 1         FirstThirdThirdSecondThirdFirstSecondSecondThi...
#
#                                                         who  adult_male  \
# survived
# 0         manmanmanmanchildmanmanchildchildwomanmanchild...         449
# ...

# %%
g2 = df.groupby("pclass")

# %%
g2.sum()
# Out:
#         survived                                                sex      age  \
# pclass
# 1            135  femalemalefemalemalemalemalefemalemalemalefema...  7076.42
# 2             87  femalefemalemalemalemalemalefemalefemalefemale...  5168.83
# 3            119  malefemalemalemalemalefemalefemalemalemalefema...  8924.92
#
#         sibsp        fare                                           embarked  \
# pclass
# 1          89  18124.3125  CSSSSCCCSCCSSCSSSCCSSCSSSCSCSSSCCSSCCCCCSSQSSC...
# 2          74   3801.8417  CSSSSSSCSSSSSSSSSSSSCSSSCSSSSSSSCSSSSSSSSSSSSS...
# 3         302   6714.6951  SSSQSSSSSSQSCQSSCQSQCSSCSCQSQQCSSSCSCSCSSSSCSS...
#
#                                                     class  \
# pclass
# 1       FirstFirstFirstFirstFirstFirstFirstFirstFirstF...
# 2       SecondSecondSecondSecondSecondSecondSecondSeco...
# 3       ThirdThirdThirdThirdThirdThirdThirdThirdThirdT...
#
#                                                       who  adult_male  \
# pclass
# ...

# %%
g2.mean(numeric_only=True)[["age"]].transpose()
# Out:
# pclass          1         2         3
# age     38.250919  29.87763  25.14062

# %%
dc1 =  df[["age", "pclass", "survived"]][0:5]

# %%
dc2 = df[["age", "pclass", "survived"]][5:10]

# %%
dc3 = pd.concat([dc1, dc2])

# %%
dc1
# Out:
#     age  pclass  survived
# 0  22.0       3         0
# 1  38.0       1         1
# 2  26.0       3         1
# 3  35.0       3         0
# 4   NaN       3         0

# %%
dc3
# Out:
#     age  pclass  survived
# 0  22.0       3         0
# 1  38.0       1         1
# 2  26.0       3         1
# 3  35.0       3         0
# 4   NaN       3         0
# 5  54.0       1         0
# 6   2.0       3         0
# 7  27.0       3         1
# 8  14.0       2         1
# 9   4.0       3         1

# %%
dc3.dropna(inplace=True)

# %%
dc3.reset_index(inplace=True)

# %%
dc3
# Out:
#    level_0  index   age  pclass  survived
# 0        0      0  22.0       3         0
# 1        1      1  38.0       1         1
# 2        2      2  26.0       3         1
# 3        3      3  35.0       3         0
# 4        4      5  54.0       1         0
# 5        5      6   2.0       3         0
# 6        6      7  27.0       3         1
# 7        7      8  14.0       2         1
# 8        8      9   4.0       3         1

# %%
pd.concat([dc1,dc2], axis=1)
# Out:
#     age  pclass  survived   age  pclass  survived
# 0  22.0     3.0       0.0   NaN     NaN       NaN
# 1  38.0     1.0       1.0   NaN     NaN       NaN
# 2  26.0     3.0       1.0   NaN     NaN       NaN
# 3  35.0     3.0       0.0   NaN     NaN       NaN
# 4   NaN     3.0       0.0   NaN     NaN       NaN
# 5   NaN     NaN       NaN  54.0     1.0       0.0
# 6   NaN     NaN       NaN   2.0     3.0       0.0
# 7   NaN     NaN       NaN  27.0     3.0       1.0
# 8   NaN     NaN       NaN  14.0     2.0       1.0
# 9   NaN     NaN       NaN   4.0     3.0       1.0

# %%
di = pd.DataFrame({'key1': [2, 5, 4, 5, 6],
 'key2': ['a', 'b', 'c', 'd', 'e'],
 'key3': [10, 20, 30, 40, 50],
 'key4': [100, 200, 300, 400, 500]})

# %%
di
# Out:
#    key1 key2  key3  key4
# 0     2    a    10   100
# 1     5    b    20   200
# 2     4    c    30   300
# 3     5    d    40   400
# 4     6    e    50   500

# %%
di2 = pd.DataFrame({'key1': [2, 5, 54, 35, 36],
 'key2': ['a', 'b', 'e', 'c', 'e'],
 'key3': [170, 260, 350, 440, 540],
 'key4': [10, 20, 30, 40, 50]})

# %%
di2
# Out:
#    key1 key2  key3  key4
# 0     2    a   170    10
# 1     5    b   260    20
# 2    54    e   350    30
# 3    35    c   440    40
# 4    36    e   540    50

# %%
pd.merge(di, di2,how="left", on="key1")
# Out:
#    key1 key2_x  key3_x  key4_x key2_y  key3_y  key4_y
# 0     2      a      10     100      a   170.0    10.0
# 1     5      b      20     200      b   260.0    20.0
# 2     4      c      30     300    NaN     NaN     NaN
# 3     5      d      40     400      b   260.0    20.0
# 4     6      e      50     500    NaN     NaN     NaN

# %%
df
# Out:
#      pclass  survived     sex   age  sibsp     fare embarked   class    who  \
# 0         3         0    male  22.0      1   7.2500        S   Third    man
# 1         1         1  female  38.0      1  71.2833        C   First  woman
# 2         3         1  female  26.0      0   7.9250        S   Third  woman
# 3         3         0    male  35.0      0   8.0500        S   Third    man
# 4         3         0    male   NaN      0   8.4583        Q   Third    man
# ..      ...       ...     ...   ...    ...      ...      ...     ...    ...
# 885       2         0    male  27.0      0  13.0000        S  Second    man
# 886       1         1  female  19.0      0  30.0000        S   First  woman
# 887       3         0  female   NaN      1  23.4500        S   Third  woman
# 888       1         1    male  26.0      0  30.0000        C   First    man
# 889       3         0    male  32.0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df["fare_inr"] = df["fare"].apply(lambda x : x*80)

# %%
df.head()
# Out:
#    pclass  survived     sex   age  sibsp     fare embarked  class    who  \
# 0       3         0    male  22.0      1   7.2500        S  Third    man
# 1       1         1  female  38.0      1  71.2833        C  First  woman
# 2       3         1  female  26.0      0   7.9250        S  Third  woman
# 3       3         0    male  35.0      0   8.0500        S  Third    man
# 4       3         0    male   NaN      0   8.4583        Q  Third    man
#
#    adult_male deck  embark_town alive  alone  fare_inr
# 0        True  NaN  Southampton    no  False   580.000
# 1       False    C    Cherbourg   yes  False  5702.664
# 2       False  NaN  Southampton   yes   True   634.000
# 3        True  NaN  Southampton    no   True   644.000
# 4        True  NaN   Queenstown    no   True   676.664

# %%
def length(x):
    return len(str(x))

df["town_length"] = df["embark_town"].apply(length)

# %%
df
# Out:
#      pclass  survived     sex   age  sibsp     fare embarked   class    who  \
# 0         3         0    male  22.0      1   7.2500        S   Third    man
# 1         1         1  female  38.0      1  71.2833        C   First  woman
# 2         3         1  female  26.0      0   7.9250        S   Third  woman
# 3         3         0    male  35.0      0   8.0500        S   Third    man
# 4         3         0    male   NaN      0   8.4583        Q   Third    man
# ..      ...       ...     ...   ...    ...      ...      ...     ...    ...
# 885       2         0    male  27.0      0  13.0000        S  Second    man
# 886       1         1  female  19.0      0  30.0000        S   First  woman
# 887       3         0  female   NaN      1  23.4500        S   Third  woman
# 888       1         1    male  26.0      0  30.0000        C   First    man
# 889       3         0    male  32.0      0   7.7500        Q   Third    man
#
# ...

# %%
def cato(x):
    if(x < 10):
        return "small"
    elif(x >= 10 and x<=20):
        return "medium"
    else: 
        return "high"

df["cato"] = df["age"].apply(cato)

# %%
df
# Out:
#      pclass  survived     sex   age  sibsp     fare embarked   class    who  \
# 0         3         0    male  22.0      1   7.2500        S   Third    man
# 1         1         1  female  38.0      1  71.2833        C   First  woman
# 2         3         1  female  26.0      0   7.9250        S   Third  woman
# 3         3         0    male  35.0      0   8.0500        S   Third    man
# 4         3         0    male   NaN      0   8.4583        Q   Third    man
# ..      ...       ...     ...   ...    ...      ...      ...     ...    ...
# 885       2         0    male  27.0      0  13.0000        S  Second    man
# 886       1         1  female  19.0      0  30.0000        S   First  woman
# 887       3         0  female   NaN      1  23.4500        S   Third  woman
# 888       1         1    male  26.0      0  30.0000        C   First    man
# 889       3         0    male  32.0      0   7.7500        Q   Third    man
#
# ...
